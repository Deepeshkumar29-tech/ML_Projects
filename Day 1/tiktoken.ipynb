# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-4o-mini")

sentences = {
    "English": "Artificial Intelligence is transforming the world.",
    "Hindi":"कृत्रिम बुद्धिमत्ता दुनिया को बदल रही है|",
    "Python": "def add(a,b): return a+b"
}

token_counts = {}

for lang, text in sentences.items():
    tokens = encoding.encode(text)
    token_counts[lang] = len(tokens)

    print(f"\n{lang} Sentence: {text}")
    print("Tokens:", tokens)
    print("Token Count:", len(tokens))
# Out:
# English Sentence: Artificial Intelligence is transforming the world.
# Tokens: [186671, 42378, 382, 64779, 290, 2375, 13]
# Token Count: 7
#
# Hindi Sentence: कृत्रिम बुद्धिमत्ता दुनिया को बदल रही है|
# Tokens: [1016, 10433, 11553, 15427, 155440, 15427, 75494, 64593, 4045, 58466, 25895, 2487, 91]
# Token Count: 13
#
# Python Sentence: def add(a,b): return a+b
# Tokens: [1314, 1147, 6271, 17568, 3127, 622, 261, 76609]
# Token Count: 8
